# %% [markdown]
# ### Week 2. Iterations and some simple computations

# %% [markdown]
# ### Last Time

# %% [markdown]
# * syntax and semantics
# * scalar objects
# * simple operations
# * expressions, variables and values
# * branching and conditionals
# * indentation
# * input & output

# %% [markdown]
# ### Today

# %% [markdown]
# * iteration and loops
# * guess and check algorithms
# * approximate solutions
# * bisection method
# * string object type
# * string manipulation

# %% [markdown]
# ### Control Flow

# %% [markdown]
# Consider an example:

# %% [markdown]
# __You are in the Lost Forest. Go left or right?__

# %%
************
************
  
************
************

# %% [markdown]
# When we want a program to do the same thing many times, we can use iteration.

# %% [markdown]
# ![Screen%20Shot%202019-09-12%20at%2011.00.24%20AM.png](attachment:Screen%20Shot%202019-09-12%20at%2011.00.24%20AM.png)

# %% [markdown]
# <font size = 3 color = Red>Control Flow: WHILE <font>

# %%
while <condition>:
    <expression>
    <expression>
    ------

# %% [markdown]
# In case of __while__ loop:
#
# * __conditon__ evaluates to a Boolean
# * if __condition__ is True, do all the steps inside the while block
# * check __condition__ again
# * repeat until __condition__ is False

# %%
n = input("You're in the lost Forest. Go left or right?")
while n == 'right':
    n = input("You're in the lost Forest. Go left or right?")
print('You got out of the Lost Forest.')

# %% [markdown]
# __How to iterate through numbers in a sequence?__

# %%
n = 0
while n<5:
    print(n)

# %%
# more complicated with while loops
n = 0
while n<5:
    print(n)
    n += 1

# %%
# shortcut with for loop
for n in range(5):
    print(n)

# %% [markdown]
# <font size = 3 color = Red>
#     Control Flow: FOR<font>

# %%
for <variable> in range(<some_num>):
    <expression>
    <expression>
    ...

# %% [markdown]
# In case of __for__ loop:
# * each time through the loop, __variable__ takes a value
# * first time, __variable__ starts at the smallest value
# * next time, __variable__ gets the prev value + 1
# * etc.

# %% [markdown]
# <font size = 3 color = Red> Range(start, stop, step)<font>

# %% [markdown]
# * default values start = 0 and step = 1 and optional
# * loop until value is stop - 1

# %%
mysum = 0
for i in range(0,7,2):
    mysum += i
print(mysum)

# %%
mysum = 0
for i in range(5, 11, 2):
    mysum += i
print(mysum)

# %%
n = 0
i = float(input())

while n*n*n != i:
    n += 1
    if n == i:
        print('goyutun chuni')
        break
print(n)

# %% [markdown]
# <font size = 3 color = Red>Break Statement<font>

# %% [markdown]
# * immediately exits whatever loop it is in
# * skips remaining expressions in code block
# * exits only innermost loop

# %%
while <condition_1>:
    while <condition_2>:
        <expression_a> 
        break
        <expression_b>
    break    
    <expression_c>

# %% [markdown]
# __what happens in this program?__

# %%
mysum = 0
for i in range(5, 11, 2):
    mysum += i
    if mysum == 5:
        break
    mysum += 1
print(mysum)

# %% [markdown]
# <font size = 3 color = Red> Continue Statement <font>

# %% [markdown]
# * immediately stops the iteration
# * skips remaining expressions in code block
# * continues with the next iteration of the smallest enclosing loop.

# %% [markdown]
# __what happens in this program?__

# %%
for num in range(2,13):
    if num % 2 == 0:
        print ('Found an even Number: ', num)
        continue
    print('Found an odd number', num)

# %% [markdown]
# <font size = 3 color = Red> Pass Statement <font>

# %% [markdown]
# * statement does nothing, which can come in handy when you are working on something and want to implement some part of your code later.

# %% [markdown]
# __what happens in this program?__

# %%
i_have_done_my_homework = True
if i_have_done_my_homework == True:
    pass
else:
    print('I should do it!')

# %% [markdown]
# <font size = 3 color = Red> Else Statement <font>

# %% [markdown]
# * statement executes the block after the loop is "done".

# %% [markdown]
# __what happens in this program?__

# %%
for i in range(10):
    print(i)
    if i == 5:
        break
else:
    print('I am done')

# %% [markdown]
# ### For VS while LOOPS

# %% [markdown]
# __for__ loops
#
# * know number of iterations
# * can end early via break
# * uses a counter
# * can rewrite a for loop using while loop

# %% [markdown]
# __while__ loops
#
# * unbounded number of iterations
# * can end early via break
# * can use a counter but must initialize before loop and increment it inside loop
# * may not be able to rewrite a while loop using a for loop

# %% [markdown]
# __Task Find the cube root of an integer:__

# %%
cube = int(input('Please provide a number'))
for guess in range(cube+1):
    if guess**3 == cube:
        print("Cube root of", cube, "is", guess)
        break
else:
    print('No cube root for this number')

# %% [markdown]
# __What if the number is negative?__

# %%
cube = 27
num_guesses = 0
for guess in range(abs(cube)+1):
    num_guesses += 1
    if guess**3 >= abs(cube):
        break
if guess**3 != abs(cube):
    print(cube, 'is not a perfect cube')
else:
    if cube < 0:
        guess = -guess
    print(num_guesses)
    print('Cube root of '+str(cube)+' is '+str(guess))

# %% [markdown]
# __Final form__

# %%
ans = 0
neg_flag = False
x = int(input("Enter an integer: "))
if x < 0:
    neg_flag = True
while ans**3 < x:
    ans = ans + 1
if ans**3 == x:
    print("Square root of", x, "is", ans)
else:
    print(x, "is not a perfect square")
    if neg_flag:
        print("Just checking... did you mean", -x, "?")

# %% [markdown]
# ### Guest and check

# %% [markdown]
# * the process above also called exhaustive enumeration
# * given a problem...
# * you are able to guess a value for solution
# * you are able to check if the solution is correct
# * keep guessing until find solution or guessed all values

# %% [markdown]
# ### A note about floats

# %%
x = 0.0
for i in range(10):
    x = x + 0.1
    if x == 1.0:
        print(x, '= 1.0')
    else:
        print(x, 'is not 1.0')
# Out:
# 0.1 is not 1.0
# 0.2 is not 1.0
# 0.30000000000000004 is not 1.0
# 0.4 is not 1.0
# 0.5 is not 1.0
# 0.6 is not 1.0
# 0.7 is not 1.0
# 0.7999999999999999 is not 1.0
# 0.8999999999999999 is not 1.0
# 0.9999999999999999 is not 1.0

# %% [markdown]
# When you first learned about decimal numbers—i.e., numbers base 10—you learned that any decimal number can be represented by a sequence of the digits 0123456789.

# %%
302 = 3*100 + 0*10 + 2*1

# %% [markdown]
# Binary numbers—numbers base 2—work similarly. A binary number is represented by a sequence of digits each of which is either 0 or 1. These digits are of- ten called bits.

# %%
101 digits represent 1*4 + 0*2 + 1*1 = 5

# %% [markdown]
# #### Floats: binary and decimal representation

# %% [markdown]
# __Decimnal representation__ -
# 0.625 would be represented as the pair (625, -3)<br>
# __Binary representation__ - would be represented as the pair (101, -11)

# %% [markdown]
# __What about 0.1?__

# %% [markdown]
# The best case will be (0011, -101) = 3/32 = 0.09375<br>
# The best case will be (11001, -1000) =  25/256 = 0.09765625<br>

# %% [markdown]
# In most Python implementations, there are 53 bits of precision available for floating point numbers

# %% [markdown]
# 0.1 = 11001100110011001100110011001100110011001100110011001<br>
# which equals 0.1000000000000000055511151231257827021181583404541015625

# %% [markdown]
# ### Approximate solutions

# %% [markdown]
# * good enough solution
# * start with a guess and increment by some small value
# * keepguessing if |guess^3-cube| >= epsilon for some small epsilon

# %%
cube = float(input())
epsilon = 0.01
guess = 0.0
increment = 0.0001
num_guesses = 0
while abs(guess**3 - cube) >= epsilon and guess <= cube :
    guess += increment
    num_guesses += 1
print('num_guesses =', num_guesses)
if abs(guess**3 - cube) >= epsilon:
    print('Failed on cube root of', cube)
else:
    print(guess, 'is close to the cube root of', cube)
